# %%
import sys
import os
sys.path.insert(0, os.path.abspath('..'))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from utils import read_log

# %%
sandbox, activities, trades = read_log('../data/logs/11bcd6a5-498e-4a8e-bbf4-1dcc77612411.log')

# %%
sandbox['lambdaLog'].iloc[0]
# Out:
# 'KELP position: 0\nKELP fair value: 2027\nBUY: 50 @ 2026\nSELL: -50 @ 2028\nRAINFOREST_RESIN position: 0\nBUY: 50 @ 9998\nSELL: -50 @ 10002'

# %%
sandbox['lambdaLog'].iloc[0].split('\n')
# Out:
# ['KELP position: 0',
#  'KELP fair value: 2027',
#  'BUY: 50 @ 2026',
#  'SELL: -50 @ 2028',
#  'RAINFOREST_RESIN position: 0',
#  'BUY: 50 @ 9998',
#  'SELL: -50 @ 10002']

# %%
activities[activities['product'] == 'KELP'].head(10)
# Out:
#     day  timestamp product  bid_price_1  bid_volume_1  bid_price_2  \
# 1    -1          0    KELP         2028             1       2026.0
# 2    -1        100    KELP         2025            24          NaN
# 5    -1        200    KELP         2025            22          NaN
# 6    -1        300    KELP         2025            31          NaN
# 9    -1        400    KELP         2025            27          NaN
# 10   -1        500    KELP         2025            30          NaN
# 13   -1        600    KELP         2026             5       2025.0
# 14   -1        700    KELP         2025             2       2024.0
# 17   -1        800    KELP         2024             1       2023.0
# 18   -1        900    KELP         2024            23          NaN
#
#     bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# 1            2.0       2025.0          29.0         2029            31
# 2            NaN          NaN           NaN         2028             2
# ...

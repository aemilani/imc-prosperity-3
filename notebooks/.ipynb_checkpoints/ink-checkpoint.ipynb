# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
def ma_model(epsilon_prev, const, theta, sigma2):
    """ X_t = const + epsilon_t + theta * epsilon_{t-1} """

    epsilon_t = np.random.normal(loc=0, scale=np.sqrt(sigma2))
    next_logr = const + epsilon_t + theta * epsilon_prev

    return next_logr

# %%
price_0 = pd.read_csv('../data/raw/round_1/prices_round_1_day_-2.csv', delimiter=';')
price_1 = pd.read_csv('../data/raw/round_1/prices_round_1_day_-1.csv', delimiter=';')
price_2 = pd.read_csv('../data/raw/round_1/prices_round_1_day_0.csv', delimiter=';')

# %%
trades_0 = pd.read_csv('../data/raw/round_1/trades_round_1_day_-2.csv', delimiter=';')
trades_1 = pd.read_csv('../data/raw/round_1/trades_round_1_day_-1.csv', delimiter=';')
trades_2 = pd.read_csv('../data/raw/round_1/trades_round_1_day_0.csv', delimiter=';')

# %% [markdown]
# # Resin

# %%
price_resin = price_0[price_0['product'] == 'RAINFOREST_RESIN']
trades_resin = trades_0[trades_0['symbol'] == 'RAINFOREST_RESIN']

# %%
plt.figure(figsize=(12, 3))
plt.scatter(price_resin.iloc[:200]['timestamp']//100, price_resin.iloc[:200]['bid_price_1'], s=price_resin.iloc[:200]['bid_volume_1'], c='tab:green')
plt.scatter(price_resin.iloc[:200]['timestamp']//100, price_resin.iloc[:200]['bid_price_2'], s=price_resin.iloc[:200]['bid_volume_2'], c='tab:green')
plt.scatter(price_resin.iloc[:200]['timestamp']//100, price_resin.iloc[:200]['bid_price_3'], s=price_resin.iloc[:200]['bid_volume_3'], c='tab:green')
plt.scatter(price_resin.iloc[:200]['timestamp']//100, price_resin.iloc[:200]['ask_price_1'], s=price_resin.iloc[:200]['ask_volume_1'], c='tab:red')
plt.scatter(price_resin.iloc[:200]['timestamp']//100, price_resin.iloc[:200]['ask_price_2'], s=price_resin.iloc[:200]['ask_volume_2'], c='tab:red')
plt.scatter(price_resin.iloc[:200]['timestamp']//100, price_resin.iloc[:200]['ask_price_3'], s=price_resin.iloc[:200]['ask_volume_3'], c='tab:red')
plt.show()

# %%
plt.figure(figsize=(12, 3))
plt.plot(price_resin['mid_price'])
plt.title('Resin Price')
plt.xlabel('time')
plt.ylabel('price')
plt.show()

# %%
plt.figure(figsize=(4, 2.5))
plt.hist(trades_resin['price'], bins=20, weights=trades_resin['quantity'])
plt.title('Resin trade prices histogram')
plt.show()

# %% [markdown]
# # Kelp

# %%
price_kelp = price_0[price_0['product'] == 'KELP']
trades_kelp = trades_0[trades_0['symbol'] == 'KELP']

# %%
plt.figure(figsize=(12, 3))
plt.scatter(price_kelp.iloc[:2000]['timestamp']//100, price_kelp.iloc[:2000]['bid_price_1'], s=price_kelp.iloc[:2000]['bid_volume_1'], c='tab:green')
plt.scatter(price_kelp.iloc[:2000]['timestamp']//100, price_kelp.iloc[:2000]['bid_price_2'], s=price_kelp.iloc[:2000]['bid_volume_2'], c='tab:green')
plt.scatter(price_kelp.iloc[:2000]['timestamp']//100, price_kelp.iloc[:2000]['bid_price_3'], s=price_kelp.iloc[:2000]['bid_volume_3'], c='tab:green')
plt.scatter(price_kelp.iloc[:2000]['timestamp']//100, price_kelp.iloc[:2000]['ask_price_1'], s=price_kelp.iloc[:2000]['ask_volume_1'], c='tab:red')
plt.scatter(price_kelp.iloc[:2000]['timestamp']//100, price_kelp.iloc[:2000]['ask_price_2'], s=price_kelp.iloc[:2000]['ask_volume_2'], c='tab:red')
plt.scatter(price_kelp.iloc[:2000]['timestamp']//100, price_kelp.iloc[:2000]['ask_price_3'], s=price_kelp.iloc[:2000]['ask_volume_3'], c='tab:red')
plt.plot(price_kelp.iloc[:2000]['timestamp']//100, price_kelp.iloc[:2000]['mid_price'], c='k', alpha=0.5)
plt.show()

# %%
trades_kelp
# Out:
#       timestamp  buyer  seller symbol   currency   price  quantity
# 0             0    NaN     NaN   KELP  SEASHELLS  2002.0         1
# 4           100    NaN     NaN   KELP  SEASHELLS  2002.0         6
# 6          1000    NaN     NaN   KELP  SEASHELLS  1999.0        10
# 8          1100    NaN     NaN   KELP  SEASHELLS  1999.0         1
# 10         1500    NaN     NaN   KELP  SEASHELLS  2002.0         1
# ...         ...    ...     ...    ...        ...     ...       ...
# 8387     997900    NaN     NaN   KELP  SEASHELLS  2026.0        12
# 8389     998000    NaN     NaN   KELP  SEASHELLS  2026.0         1
# 8390     998000    NaN     NaN   KELP  SEASHELLS  2027.0         4
# 8393     998900    NaN     NaN   KELP  SEASHELLS  2029.0         1
# 8395     999000    NaN     NaN   KELP  SEASHELLS  2030.0         9
#
# [2957 rows x 7 columns]

# %%
plt.figure(figsize=(6, 3))
plt.plot(price_kelp['mid_price'])
plt.title('Kelp Price')
plt.xlabel('time')
plt.ylabel('price')
plt.show()

# %% [markdown]
# ## Price prediction - mid price

# %%
train = price_0[price_0['product'] == 'KELP']['mid_price'].to_numpy()
valid = price_1[price_1['product'] == 'KELP']['mid_price'].to_numpy()
test = price_2[price_2['product'] == 'KELP']['mid_price'].to_numpy()

# %%
train_logr = np.log(train[1:] / train[:-1])
valid_logr = np.log(valid[1:] / valid[:-1])
test_logr = np.log(test[1:] / test[:-1])

# %%
plt.figure(figsize=(6, 3))
plt.plot(train_logr)
plt.title('Kelp Log Returns')
plt.xlabel('time')
plt.ylabel('Log Return')
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 3))
plot_acf(train_logr, ax=ax[0], zero=False)
plot_pacf(train_logr, ax=ax[1], zero=False)
ax[0].set_xlim([0, 15])
ax[1].set_xlim([0, 15])
plt.show()

# %% [markdown]
# - the PACF is exponentially decaying or sinusoidal;
# - there is a significant spike at lag q=1 in the ACF, but none beyond lag q=1.
# - -> ARIMA(0,1,1) or MA(1)

# %% [markdown]
# ### Naive

# %%
y = test[1:]
y_pred = test[:-1]
err = y - y_pred
rmse = np.mean(err ** 2) ** 0.5
print(rmse)
# Out:
# 0.77645688130691

# %%
plt.figure(figsize=(6, 3))
plt.plot(y)
plt.plot(y_pred)
plt.title('True and predicted price - Naive')
plt.xlabel('time')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# ### MA(1)

# %%
model = ARIMA(train_logr, order=(0, 0, 1))
result = model.fit()
print(result.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                  999
# Model:                 ARIMA(0, 0, 1)   Log Likelihood                6671.914
# Date:                Mon, 07 Apr 2025   AIC                         -13337.828
# Time:                        15:04:39   BIC                         -13323.108
# Sample:                             0   HQIC                        -13332.233
#                                 - 999
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.412e-06   3.66e-06     -0.385      0.700   -8.59e-06    5.77e-06
# ma.L1         -0.6284      0.027    -22.947      0.000      -0.682      -0.575
# sigma2      9.432e-08   3.64e-09     25.891      0.000    8.72e-08    1.01e-07
# ...

# %%
result.params
# Out:
# array([-1.41204384e-06, -6.28382306e-01,  9.43236625e-08])

# %%
errs = [test_logr[0] - 0]
preds = [0]
for i in range(1, len(test_logr)):
    pred = ma_model(epsilon_prev=errs[i-1], const=result.params[0], theta=result.params[1], sigma2=result.params[2])
    err = test_logr[i] - pred
    preds.append(pred)
    errs.append(err)

# %%
plt.figure(figsize=(12, 4))
plt.plot(test_logr, label='True')
plt.plot(preds, label='Predicted')
plt.title('Kelp Log Returns')
plt.xlabel('time')
plt.ylabel('Log Return')
plt.legend()
plt.show()

# %%
pred_price = test[:-1] * np.exp(preds)

# %%
err = test[1:] - pred_price
rmse = np.mean(err ** 2) ** 0.5
print(rmse)
# Out:
# 1.0183329077258367

# %%
plt.figure(figsize=(6, 3))
plt.plot(test[1:])
plt.plot(pred_price)
plt.title('True and predicted price - MA(1)')
plt.xlabel('time')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# # Ink

# %%
price_ink = price_0[price_0['product'] == 'SQUID_INK']
trades_ink = trades_0[trades_0['symbol'] == 'SQUID_INK']

# %%
plt.figure(figsize=(6, 3))
plt.plot(price_ink['mid_price'])
plt.title('Ink Price')
plt.xlabel('time')
plt.ylabel('price')
plt.show()

# %% [markdown]
# ## Price prediction

# %%
train = price_0[price_0['product'] == 'SQUID_INK']['mid_price'].to_numpy()
valid = price_1[price_1['product'] == 'SQUID_INK']['mid_price'].to_numpy()
test = price_2[price_2['product'] == 'SQUID_INK']['mid_price'].to_numpy()

# %%
train_logr = np.log(train[1:] / train[:-1])
valid_logr = np.log(valid[1:] / valid[:-1])
test_logr = np.log(test[1:] / test[:-1])

# %%
plt.figure(figsize=(6, 3))
plt.plot(train_logr)
plt.title('Ink Log Returns')
plt.xlabel('time')
plt.ylabel('Log Return')
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 3))
plot_acf(train_logr, ax=ax[0], zero=False)
plot_pacf(train_logr, ax=ax[1], zero=False)
ax[0].set_xlim([0, 15])
ax[1].set_xlim([0, 15])
ax[0].set_ylim([-0.25, 0.25])
ax[1].set_ylim([-0.25, 0.25])
plt.show()
